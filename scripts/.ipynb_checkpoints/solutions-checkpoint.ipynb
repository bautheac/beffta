# %% [markdown]
# ## full stack data science finance (small) project

# %%
import pandas as pd; import numpy as np
import matplotlib.pyplot as plt; import seaborn as sns
import statsmodels.api as sm; import scipy.stats as ss
from sklearn.linear_model import LinearRegression
import scipy.linalg as la

workbook, N, ticker_market = pd.ExcelFile('../data-raw/pullit - RAY Index.xlsm'), 252, 'RAY Index'
tickers = pd.read_excel(workbook, sheet_name = 'update', usecols = 'D', dtype = 'str').ticker.values

# %%
static = pd.read_excel(workbook, sheet_name = 'update', usecols = 'D, F, G')
static = static.loc[static['ticker'] != ticker_market].set_index('ticker')

historical = {ticker: pd.read_excel(workbook, skiprows = 1, sheet_name  = ticker)
        for ticker in tickers}
historical = pd.concat(historical.values(), keys = historical.keys()).dropna(subset = ['Date'])\
    .reset_index().drop('level_1', axis = 1)
historical.rename(columns = {'level_0': 'ticker', 'Date': 'date'}, inplace = True)
historical.set_index(['ticker', 'date'], inplace = True)

# %%
betas = historical[['PX_LAST']].unstack('ticker').xs('PX_LAST', axis = 1, drop_level = True)\
    .pct_change().dropna(how = 'all').iloc[-N:, ]

market = betas[ticker_market]; betas.drop(ticker_market, axis = 1, inplace = True)

betas = betas.apply(lambda stock: ss.linregress(x = market, y = stock).slope, axis = 0)
betas = pd.DataFrame(betas).reset_index(); betas.columns = ['ticker', 'beta']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
betas
# Out:
#             ticker      beta
# 0    AGX US Equity  0.719720
# 1   AJRD US Equity  1.097891
# 2    ALG US Equity  0.854246
# 3    AMD US Equity  1.663742
# 4   AMZN US Equity  1.282357
# 5    ANF US Equity  1.221051
# 6    AVT US Equity  1.018318
# 7    AVX US Equity  0.904600
# 8   BFAM US Equity  0.783014
# 9   BKNG US Equity  0.808867
# 10   BSX US Equity  1.053340
# 11   BTU US Equity  0.915639
# 12  BURL US Equity  0.807441
# 13  CATO US Equity  0.406358
# 14   CHS US Equity  0.209864
# 15   CIX US Equity  0.411278
# 16  CMPR US Equity  0.742447
# 17  CNXN US Equity  0.861669
# 18  COHU US Equity  1.382874
# 19   CRL US Equity  1.085149
# 20   CTB US Equity  1.004941
# 21  CTXS US Equity  0.829476
# 22   DHI US Equity  0.942806
# 23   EBF US Equity  0.569916
# 24  EEFT US Equity  0.977061
# 25   EML US Equity  0.866871
# 26   ENV US Equity  1.055229
# 27  ESCA US Equity  0.492261
# 28  EXTR US Equity  1.396381
# 29   FDC US Equity  0.932591
# ..             ...       ...
# 70  PLPC US Equity  1.007172
# 71  PRAH US Equity  1.036883
# 72  PRPL US Equity  0.044303
# 73   PTC US Equity  1.217779
# 74   RBC US Equity  1.136631
# 75  RCKY US Equity  0.696769
# 76  RDNT US Equity  0.546765
# 77    RH US Equity  1.063511
# 78    RS US Equity  1.115720
# 79  SAFM US Equity  0.481034
# 80  SCHN US Equity  1.169693
# 81  SCVL US Equity  0.686936
# 82  SEAS US Equity  0.621983
# 83   SFM US Equity  0.720415
# 84   SGA US Equity  0.581203
# 85   SIG US Equity  0.636146
# 86  SNDR US Equity  1.051083
# 87   TCX US Equity  0.476719
# 88   TDC US Equity  0.898019
# 89  TNET US Equity  0.963866
# 90   TRU US Equity  0.915888
# 91  UFPI US Equity  0.934883
# 92   UFS US Equity  1.087580
# 93   UVV US Equity  0.259427
# 94  VRSK US Equity  0.881077
# 95   VSH US Equity  1.142381
# 96   WBT US Equity  0.764462
# 97   WLK US Equity  1.121460
# 98  ZAYO US Equity  0.550679
# 99  ZBRA US Equity  1.116828
#
# [100 rows x 2 columns]

# %%
# %matplotlib notebook

betas = pd.concat([pd.DataFrame({'index': range(1, len(betas))}),
                 betas[['beta']].sort_values('beta').reset_index(drop = True)], axis=1)

fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot('index', 'beta', 'go', alpha = 0.25, data = betas)
ax.set_title("1-year trailing market betas")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'1-year trailing market betas')

# %%
betas = data[['PX_LAST']].unstack('ticker').xs('PX_LAST', axis = 1, drop_level = True)\
    .pct_change().dropna(how = 'all')

market = betas[ticker_market]; betas.drop(ticker_market, axis = 1, inplace = True)

betas = {betas.index[i].strftime('%Y-%m-%d'): betas.iloc[(i - N):i, ]\
         .apply(lambda column: ss.linregress(x = market[(i - N):i], y = column).slope, axis = 0)
         for i in range(N, len(betas))}
betas = pd.DataFrame(pd.concat(betas, ignore_index = False)).reset_index()\
    .rename(columns = {'level_0': 'date', 0: 'beta'}).dropna()\
    .set_index(['date', 'ticker']).unstack('ticker').\
    xs('beta', axis = 1, drop_level = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
betas[['AVX US Equity', 'SGA US Equity']].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Ratios
#
# #### Values

# %%
betas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b820eef417a2> in <module>()
# ----> 1 betas
#
# NameError: name 'betas' is not defined

# %%
beta = betas[-1:].T.reset_index(); beta.columns = ['ticker', 'beta']
data = historical.groupby(level = 'ticker').last().reset_index()\
    .loc[:, ['ticker', 'PX_LAST', 'BOOK_VAL_PER_SH', 'TRAIL_12M_EPS', 
             'TRAIL_12M_DVD_PER_SH', 'SHORT_AND_LONG_TERM_DEBT', 'TOTAL_EQUITY']]

data = pd.merge(data, beta, on = 'ticker').set_index('ticker')
data['price / book'] = data['PX_LAST'] / data['BOOK_VAL_PER_SH']
data['price / earnings'] = data['PX_LAST'] / data['TRAIL_12M_EPS']
data['dividend yield'] = data['TRAIL_12M_DVD_PER_SH'] / data['PX_LAST']
data['debt / equity'] = data['SHORT_AND_LONG_TERM_DEBT'] / data['TOTAL_EQUITY']
data = data[['price / book', 'price / earnings', 'dividend yield']]
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ae5819c8d773> in <module>()
# ----> 1 beta = betas[-1:].T.reset_index(); beta.columns = ['ticker', 'beta']
#       2 data = historical.groupby(level = 'ticker').last().reset_index()    .loc[:, ['ticker', 'PX_LAST', 'BOOK_VAL_PER_SH', 'TRAIL_12M_EPS',
#       3              'TRAIL_12M_DVD_PER_SH', 'SHORT_AND_LONG_TERM_DEBT', 'TOTAL_EQUITY']]
#       4
#       5 data = pd.merge(data, beta, on = 'ticker').set_index('ticker')
#
# NameError: name 'betas' is not defined

# %%
sns.pairplot(data, diag_kind = 'kde')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
from sklearn.preprocessing import StandardScaler
scaled = StandardScaler().fit_transform(data)

from scipy.cluster.hierarchy import dendrogram, ward

linkage_array = ward(scaled)
dendrogram(linkage_array)

ax = plt.gca()
bounds = ax.get_xbound()
ax.plot(bounds, [9, 9], '--', c='k')
ax.plot(bounds, [7, 7], '--', c='k')
ax.text(bounds[1], 9, ' two clusters', va='center', fontdict={'size': 15})
ax.text(bounds[1], 7, ' three clusters', va='center', fontdict={'size': 15})
plt.xlabel("Sample index")
plt.ylabel("Cluster distance")
# Out:
# Text(772.498,0.5,'Cluster distance')

# %%
import feather as ftr
# ?ftr
